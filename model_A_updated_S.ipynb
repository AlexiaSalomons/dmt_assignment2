# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
import copy
import gc
from sklearn.model_selection import train_test_split
from sklearn.metrics import ndcg_score
from sklearn.impute import SimpleImputer
import math

# %%
def replace_nan_with_mean(df,cols):
    """
    Completing missing numerical values (NaN) from columns. NaN values are replaced by the column's mean
    Args:
        @string_cols:  (list of column indexes) string columns to complete
    """
    imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

    imp_mean = imp_mean.fit(df[cols])

    df[cols] = imp_mean.transform(df[cols])

    return df

# %%
def replace_nan_with_median(df,cols):
    imp_mean = SimpleImputer(missing_values=np.nan, strategy='median')

    imp_mean = imp_mean.fit(df[cols])

    df[cols] = imp_mean.transform(df[cols])

    return df

# %%
def replace_nan_with_value(df,col,value):
    imp_mean = SimpleImputer(missing_values=np.nan, strategy='constant',fill_value=value)

    imp_mean = imp_mean.fit(df[[col]])

    df[col] = imp_mean.transform(df[[col]])

    return df

# %%
# !kaggle competitions download -c vu-dmt-assigment-2-2023
training_data = pd.read_csv('vu-dmt-assigment-2-2023/training_set_VU_DM.csv')
test_data = pd.read_csv('vu-dmt-assigment-2-2023/test_set_VU_DM.csv')

# %%
#create new column for NDCG evaluation
training_data['target_col'] = (5* training_data['booking_bool']) + training_data['click_bool']

# %%
#Create one location score column
training_data['prop_loc_score1_norm'] = training_data['prop_location_score1'] / training_data['prop_location_score1'].abs().max()
training_data['prop_location_score2'].fillna(training_data['prop_loc_score1_norm'], inplace=True)
training_data['location_score'] = (training_data['prop_loc_score1_norm'] + training_data['prop_location_score2'])/2
training_data = training_data.drop('prop_loc_score1_norm', axis=1)
# training_data['location_score'] = ((training_data['prop_location_score1'] + training_data['prop_location_score2']) / 2)

# %%
#Count how often a prop_id shows up
z = training_data['prop_id'].value_counts() 
z1 = z.to_dict() #converts to dictionary
training_data['Count_Column'] = training_data['prop_id'].map(z1)

# %%
# Get data for whether the hotel is more expensive than usual
training_data['diff_price'] = ((training_data['price_usd']) - (np.exp(training_data['prop_log_historical_price'])))

# %%
training_data.to_csv("training_set_TRANS.csv", index=False)

# %% [markdown]
# Run from here for data

# %%
test_data = pd.read_csv('vu-dmt-assigment-2-2023/test_set_VU_DM.csv')

# %%
training_data = pd.read_csv("training_set_TRANS.csv")

# %%
gc.collect()
# Out:
# 34

# %%
aux_training = copy.copy(training_data)

# %%
aux_training
# Out:
#          srch_id            date_time  site_id  visitor_location_country_id  \
# 0              1  2013-04-04 08:32:15       12                          187
# 1              1  2013-04-04 08:32:15       12                          187
# 2              1  2013-04-04 08:32:15       12                          187
# 3              1  2013-04-04 08:32:15       12                          187
# 4              1  2013-04-04 08:32:15       12                          187
# ...          ...                  ...      ...                          ...
# 4958342   332785  2013-06-30 19:55:18        5                          219
# 4958343   332785  2013-06-30 19:55:18        5                          219
# 4958344   332785  2013-06-30 19:55:18        5                          219
# 4958345   332785  2013-06-30 19:55:18        5                          219
# 4958346   332785  2013-06-30 19:55:18        5                          219
#
#          visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  \
# 0                            NaN                   NaN              219
# 1                            NaN                   NaN              219
# 2                            NaN                   NaN              219
# 3                            NaN                   NaN              219
# 4                            NaN                   NaN              219
# ...                          ...                   ...              ...
# 4958342                      NaN                   NaN              219
# 4958343                      NaN                   NaN              219
# 4958344                      NaN                   NaN              219
# 4958345                      NaN                   NaN              219
# 4958346                      NaN                   NaN              219
#
#          prop_id  prop_starrating  prop_review_score  ...  comp8_rate  \
# 0            893                3                3.5  ...         0.0
# 1          10404                4                4.0  ...         0.0
# 2          21315                3                4.5  ...         0.0
# 3          27348                2                4.0  ...        -1.0
# 4          29604                4                3.5  ...         0.0
# ...          ...              ...                ...  ...         ...
# 4958342    77700                3                4.0  ...         NaN
# 4958343    88083                3                4.0  ...         NaN
# 4958344    94508                3                3.5  ...         NaN
# 4958345   128360                3                5.0  ...         NaN
# 4958346   134949                3                2.5  ...         NaN
#
#          comp8_inv  comp8_rate_percent_diff  click_bool  gross_bookings_usd  \
# 0              0.0                      NaN           0                 NaN
# 1              0.0                      NaN           0                 NaN
# 2              0.0                      NaN           0                 NaN
# 3              0.0                      5.0           0                 NaN
# 4              0.0                      NaN           0                 NaN
# ...            ...                      ...         ...                 ...
# 4958342        NaN                      NaN           0                 NaN
# 4958343        NaN                      NaN           0                 NaN
# 4958344        NaN                      NaN           0                 NaN
# 4958345        NaN                      NaN           1              157.84
# 4958346        NaN                      NaN           0                 NaN
#
#          booking_bool  target_col  location_score  Count_Column  diff_price
# 0                   0           0        0.224622           612  -36.404964
# 1                   0           0        0.165043           583   17.806987
# 2                   0           0        0.169843           551   42.797387
# 3                   0           0        0.208972           460  522.129581
# 4                   0           0        0.251162           665    5.200488
# ...               ...         ...             ...           ...         ...
# 4958342             0           0        0.138880            47  117.000000
# 4958343             0           0        0.215685            38   88.000000
# 4958344             0           0        0.086997            43   98.000000
# 4958345             1           6        0.172785            37  138.000000
# 4958346             0           0        0.157593            12   60.000000
#
# [4958347 rows x 58 columns]

# %%
aux_training = replace_nan_with_mean(aux_training,["visitor_hist_starrating","visitor_hist_adr_usd"])
aux_training = replace_nan_with_mean(aux_training,["diff_price"])
aux_training = replace_nan_with_mean(aux_training,['comp1_rate_percent_diff','comp1_rate','comp2_rate_percent_diff','comp2_rate',
                                 'comp3_rate_percent_diff','comp3_rate','comp4_rate_percent_diff','comp4_rate',
                                 'comp5_rate_percent_diff','comp5_rate','comp6_rate_percent_diff','comp6_rate',
                                 'comp7_rate_percent_diff','comp7_rate','comp8_rate_percent_diff','comp8_rate'])
aux_training = replace_nan_with_median(aux_training,["orig_destination_distance"])

col_min = aux_training["srch_query_affinity_score"].min() # minimum of col
aux_training = replace_nan_with_value(aux_training,'srch_query_affinity_score',col_min)

col_min = aux_training["prop_starrating"].min() # minimum of col
aux_training = replace_nan_with_value(aux_training,'prop_starrating',col_min)

col_min = aux_training["prop_review_score"].min() # minimum of col
aux_training = replace_nan_with_value(aux_training,'prop_review_score',col_min)

col_min = aux_training["location_score"].min() # minimum of col
aux_training = replace_nan_with_value(aux_training,'location_score',col_min)

# %%
aux_training['comp_rate_percent_diff'] = (((aux_training['comp1_rate_percent_diff'] * aux_training['comp1_rate']) +
                                            (aux_training['comp2_rate_percent_diff'] * aux_training['comp2_rate']) +
                                            (aux_training['comp3_rate_percent_diff'] * aux_training['comp3_rate']) +
                                            (aux_training['comp4_rate_percent_diff'] * aux_training['comp4_rate']) + 
                                            (aux_training['comp5_rate_percent_diff'] * aux_training['comp5_rate']) +
                                            (aux_training['comp6_rate_percent_diff'] * aux_training['comp6_rate']) +
                                            (aux_training['comp7_rate_percent_diff'] * aux_training['comp7_rate']) +
                                            (aux_training['comp8_rate_percent_diff'] * aux_training['comp8_rate'])) / 8)

# %%
aux_training
# Out:
#          srch_id            date_time  site_id  visitor_location_country_id  \
# 0              1  2013-04-04 08:32:15       12                          187
# 1              1  2013-04-04 08:32:15       12                          187
# 2              1  2013-04-04 08:32:15       12                          187
# 3              1  2013-04-04 08:32:15       12                          187
# 4              1  2013-04-04 08:32:15       12                          187
# ...          ...                  ...      ...                          ...
# 4958342   332785  2013-06-30 19:55:18        5                          219
# 4958343   332785  2013-06-30 19:55:18        5                          219
# 4958344   332785  2013-06-30 19:55:18        5                          219
# 4958345   332785  2013-06-30 19:55:18        5                          219
# 4958346   332785  2013-06-30 19:55:18        5                          219
#
#          visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  \
# 0                       3.374334            176.022659              219
# 1                       3.374334            176.022659              219
# 2                       3.374334            176.022659              219
# 3                       3.374334            176.022659              219
# 4                       3.374334            176.022659              219
# ...                          ...                   ...              ...
# 4958342                 3.374334            176.022659              219
# 4958343                 3.374334            176.022659              219
# 4958344                 3.374334            176.022659              219
# 4958345                 3.374334            176.022659              219
# 4958346                 3.374334            176.022659              219
#
#          prop_id  prop_starrating  prop_review_score  ...  comp8_inv  \
# 0            893                3                3.5  ...        0.0
# 1          10404                4                4.0  ...        0.0
# 2          21315                3                4.5  ...        0.0
# 3          27348                2                4.0  ...        0.0
# 4          29604                4                3.5  ...        0.0
# ...          ...              ...                ...  ...        ...
# 4958342    77700                3                4.0  ...        NaN
# 4958343    88083                3                4.0  ...        NaN
# 4958344    94508                3                3.5  ...        NaN
# 4958345   128360                3                5.0  ...        NaN
# 4958346   134949                3                2.5  ...        NaN
#
#          comp8_rate_percent_diff  click_bool  gross_bookings_usd  \
# 0                      22.430384           0                 NaN
# 1                      22.430384           0                 NaN
# 2                      22.430384           0                 NaN
# 3                       5.000000           0                 NaN
# 4                      22.430384           0                 NaN
# ...                          ...         ...                 ...
# 4958342                22.430384           0                 NaN
# 4958343                22.430384           0                 NaN
# 4958344                22.430384           0                 NaN
# 4958345                22.430384           1              157.84
# 4958346                22.430384           0                 NaN
#
#          booking_bool  target_col  location_score  Count_Column  diff_price  \
# 0                   0           0        0.224622           612  -36.404964
# 1                   0           0        0.165043           583   17.806987
# 2                   0           0        0.169843           551   42.797387
# 3                   0           0        0.208972           460  522.129581
# 4                   0           0        0.251162           665    5.200488
# ...               ...         ...             ...           ...         ...
# 4958342             0           0        0.138880            47  117.000000
# 4958343             0           0        0.215685            38   88.000000
# 4958344             0           0        0.086997            43   98.000000
# 4958345             1           6        0.172785            37  138.000000
# 4958346             0           0        0.157593            12   60.000000
#
#          comp_rate_percent_diff
# 0                     14.916091
# 1                     15.018229
# 2                     14.916091
# 3                     13.041091
# 4                     14.916091
# ...                         ...
# 4958342               14.990604
# 4958343               14.990604
# 4958344               14.990604
# 4958345               14.990604
# 4958346               14.990604
#
# [4958347 rows x 59 columns]

# %%
aux_training = aux_training.drop('click_bool', axis=1)   #replaced by target_col and not in test set 
aux_training = aux_training.drop('booking_bool', axis=1) #replaced by target_col and not in test set 
aux_training = aux_training.drop('position', axis=1)     # not in test set 
aux_training = aux_training.drop('gross_bookings_usd', axis=1)
aux_training = aux_training.drop('prop_location_score1', axis=1)
aux_training = aux_training.drop('prop_location_score2', axis=1)
aux_training = aux_training.drop(['date_time'], axis=1)
aux_training = aux_training.drop(['comp1_rate_percent_diff','comp1_rate','comp2_rate_percent_diff','comp2_rate',
                                 'comp3_rate_percent_diff','comp3_rate','comp4_rate_percent_diff','comp4_rate',
                                 'comp5_rate_percent_diff','comp5_rate','comp6_rate_percent_diff','comp6_rate',
                                 'comp7_rate_percent_diff','comp7_rate','comp8_rate_percent_diff','comp8_rate'], axis=1)

# %%
print("Empty values per column: \n",aux_training.isnull().sum())
# Out:
# Empty values per column:
#  srch_id                              0
# site_id                              0
# visitor_location_country_id          0
# visitor_hist_starrating              0
# visitor_hist_adr_usd                 0
# prop_country_id                      0
# prop_id                              0
# prop_starrating                      0
# prop_review_score                    0
# prop_brand_bool                      0
# prop_log_historical_price            0
# price_usd                            0
# promotion_flag                       0
# srch_destination_id                  0
# srch_length_of_stay                  0
# srch_booking_window                  0
# srch_adults_count                    0
# srch_children_count                  0
# srch_room_count                      0
# srch_saturday_night_bool             0
# srch_query_affinity_score            0
# orig_destination_distance            0
# random_bool                          0
# comp1_inv                      4828788
# comp2_inv                      2828078
# comp3_inv                      3307357
# comp4_inv                      4614684
# comp5_inv                      2598327
# comp6_inv                      4697371
# comp7_inv                      4601925
# comp8_inv                      2970844
# target_col                           0
# location_score                       0
# Count_Column                         0
# diff_price                           0
# comp_rate_percent_diff               0
# dtype: int64

# %%
#Separate features from target
feature = aux_training.drop('target_col', axis=1)
target  = aux_training['target_col']

# %%
X_train, X_val, y_train, y_val = train_test_split(feature, target, test_size=0.3, random_state=1)

# %%
print("X_train.shape = ",X_train.shape)
print("X_val.shape = ",X_val.shape)
print("\ny_train.shape = ",y_train.shape)
print("y_val.shape = ",y_val.shape)
# Out:
# X_train.shape =  (3470842, 35)
# X_val.shape =  (1487505, 35)
#
# y_train.shape =  (3470842,)
# y_val.shape =  (1487505,)

# %%
X_train = X_train.sort_index()
y_train = y_train.sort_index()

X_val = X_val.sort_index()
y_val = y_val.sort_index()

# %%
# Get the number of rows of each query (srch_id) needed to train the model.
qids_train = X_train.groupby("srch_id")["srch_id"].count().to_numpy() 
qids_val   = X_val.groupby("srch_id")["srch_id"].count().to_numpy()

# %%
print("query train ids mean: ",qids_train.mean()) 
print("query val   ids mean: ",qids_val.mean())
# Out:
# query train ids mean:  17.37427729027026
# query val   ids mean:  7.532433664168523

# %%
FIXED_PARAMS={
              'objective'             : 'rank_xendcg', #supposed to be faster than 'lambdarank'
              'metric'                : 'ndcg',
              'boosting_type'         : 'dart',
              'is_unbalance'          : True,
              'num_iterations'        : 100,
              'early_stopping_rounds' : 10}

SEARCH_PARAMS = {'learning_rate': 0.15,
                 'max_depth': 15,
                 'num_leaves': 25,
                 'feature_fraction': 0.8,
                 'subsample': 0.2,
                 'n_estimators' : 100}

gbm = lgb.LGBMRanker( 
        objective               = FIXED_PARAMS["objective"],
        metric                  = FIXED_PARAMS["metric"],
        boosting_type           = FIXED_PARAMS["boosting_type"],
        is_unbalance            = FIXED_PARAMS["is_unbalance"],
        num_iterations          = FIXED_PARAMS["num_iterations"],
        early_stopping_rounds   = FIXED_PARAMS["early_stopping_rounds"],
        learning_rate           = SEARCH_PARAMS["learning_rate"],
        max_depth               = SEARCH_PARAMS["max_depth"],
        num_leaves              = SEARCH_PARAMS["num_leaves"],
        feature_fraction        = SEARCH_PARAMS["feature_fraction"],
        subsample               = SEARCH_PARAMS["subsample"],
        n_estimators            = SEARCH_PARAMS["n_estimators"],
)

# %%
gbm.fit(X_train, 
        y_train, 
        group=qids_train,
        eval_set=[(X_val, y_val)], 
        eval_group=[qids_val],
        eval_at=[1,2,3,4,5]
)
# Out:
# C:\Users\sandr\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] early_stopping_round is set=10, early_stopping_rounds=10 will be ignored. Current value: early_stopping_round=10
# [1]	valid_0's ndcg@1: 0.763295	valid_0's ndcg@2: 0.800467	valid_0's ndcg@3: 0.822309	valid_0's ndcg@4: 0.836886	valid_0's ndcg@5: 0.846911
# C:\Users\sandr\anaconda3\lib\site-packages\lightgbm\callback.py:223: UserWarning: Early stopping is not available in dart mode
#   _log_warning('Early stopping is not available in dart mode')
# [2]	valid_0's ndcg@1: 0.766891	valid_0's ndcg@2: 0.804176	valid_0's ndcg@3: 0.826099	valid_0's ndcg@4: 0.840357	valid_0's ndcg@5: 0.850221
# [3]	valid_0's ndcg@1: 0.769353	valid_0's ndcg@2: 0.807342	valid_0's ndcg@3: 0.828853	valid_0's ndcg@4: 0.843122	valid_0's ndcg@5: 0.853112
# [4]	valid_0's ndcg@1: 0.771364	valid_0's ndcg@2: 0.80903	valid_0's ndcg@3: 0.830847	valid_0's ndcg@4: 0.845107	valid_0's ndcg@5: 0.854792
# [5]	valid_0's ndcg@1: 0.77235	valid_0's ndcg@2: 0.810248	valid_0's ndcg@3: 0.832102	valid_0's ndcg@4: 0.846331	valid_0's ndcg@5: 0.856051
# [6]	valid_0's ndcg@1: 0.773257	valid_0's ndcg@2: 0.811399	valid_0's ndcg@3: 0.833042	valid_0's ndcg@4: 0.847085	valid_0's ndcg@5: 0.856892
# [7]	valid_0's ndcg@1: 0.774072	valid_0's ndcg@2: 0.812273	valid_0's ndcg@3: 0.833804	valid_0's ndcg@4: 0.847781	valid_0's ndcg@5: 0.857548
# [8]	valid_0's ndcg@1: 0.774082	valid_0's ndcg@2: 0.812364	valid_0's ndcg@3: 0.833811	valid_0's ndcg@4: 0.847932	valid_0's ndcg@5: 0.857619
# [9]	valid_0's ndcg@1: 0.774933	valid_0's ndcg@2: 0.813242	valid_0's ndcg@3: 0.834702	valid_0's ndcg@4: 0.848683	valid_0's ndcg@5: 0.858506
# [10]	valid_0's ndcg@1: 0.775992	valid_0's ndcg@2: 0.814309	valid_0's ndcg@3: 0.835964	valid_0's ndcg@4: 0.849912	valid_0's ndcg@5: 0.85942
# [11]	valid_0's ndcg@1: 0.776346	valid_0's ndcg@2: 0.814941	valid_0's ndcg@3: 0.836451	valid_0's ndcg@4: 0.850286	valid_0's ndcg@5: 0.859797
# [12]	valid_0's ndcg@1: 0.776351	valid_0's ndcg@2: 0.814819	valid_0's ndcg@3: 0.836349	valid_0's ndcg@4: 0.850263	valid_0's ndcg@5: 0.859816
# [13]	valid_0's ndcg@1: 0.776863	valid_0's ndcg@2: 0.815478	valid_0's ndcg@3: 0.836822	valid_0's ndcg@4: 0.850801	valid_0's ndcg@5: 0.86012
# [14]	valid_0's ndcg@1: 0.777222	valid_0's ndcg@2: 0.81585	valid_0's ndcg@3: 0.837284	valid_0's ndcg@4: 0.851144	valid_0's ndcg@5: 0.860517
# [15]	valid_0's ndcg@1: 0.777713	valid_0's ndcg@2: 0.816411	valid_0's ndcg@3: 0.837851	valid_0's ndcg@4: 0.851599	valid_0's ndcg@5: 0.860854
# [16]	valid_0's ndcg@1: 0.777891	valid_0's ndcg@2: 0.816629	valid_0's ndcg@3: 0.838172	valid_0's ndcg@4: 0.851789	valid_0's ndcg@5: 0.861085
# [17]	valid_0's ndcg@1: 0.778402	valid_0's ndcg@2: 0.81707	valid_0's ndcg@3: 0.838465	valid_0's ndcg@4: 0.852145	valid_0's ndcg@5: 0.861409
# [18]	valid_0's ndcg@1: 0.778954	valid_0's ndcg@2: 0.817517	valid_0's ndcg@3: 0.838939	valid_0's ndcg@4: 0.852672	valid_0's ndcg@5: 0.861915
# [19]	valid_0's ndcg@1: 0.779071	valid_0's ndcg@2: 0.817795	valid_0's ndcg@3: 0.83915	valid_0's ndcg@4: 0.852851	valid_0's ndcg@5: 0.862132
# [20]	valid_0's ndcg@1: 0.77941	valid_0's ndcg@2: 0.818253	valid_0's ndcg@3: 0.839638	valid_0's ndcg@4: 0.853347	valid_0's ndcg@5: 0.862554
# [21]	valid_0's ndcg@1: 0.779349	valid_0's ndcg@2: 0.818324	valid_0's ndcg@3: 0.839606	valid_0's ndcg@4: 0.853388	valid_0's ndcg@5: 0.862549
# [22]	valid_0's ndcg@1: 0.779506	valid_0's ndcg@2: 0.81857	valid_0's ndcg@3: 0.839853	valid_0's ndcg@4: 0.853607	valid_0's ndcg@5: 0.86282
# [23]	valid_0's ndcg@1: 0.779845	valid_0's ndcg@2: 0.818791	valid_0's ndcg@3: 0.840171	valid_0's ndcg@4: 0.853861	valid_0's ndcg@5: 0.863088
# [24]	valid_0's ndcg@1: 0.780027	valid_0's ndcg@2: 0.819161	valid_0's ndcg@3: 0.840455	valid_0's ndcg@4: 0.854074	valid_0's ndcg@5: 0.8633
# [25]	valid_0's ndcg@1: 0.780336	valid_0's ndcg@2: 0.819406	valid_0's ndcg@3: 0.840682	valid_0's ndcg@4: 0.854337	valid_0's ndcg@5: 0.863518
# [26]	valid_0's ndcg@1: 0.780463	valid_0's ndcg@2: 0.819616	valid_0's ndcg@3: 0.840868	valid_0's ndcg@4: 0.854448	valid_0's ndcg@5: 0.863698
# [27]	valid_0's ndcg@1: 0.780752	valid_0's ndcg@2: 0.819907	valid_0's ndcg@3: 0.841219	valid_0's ndcg@4: 0.854818	valid_0's ndcg@5: 0.863943
# [28]	valid_0's ndcg@1: 0.780539	valid_0's ndcg@2: 0.819813	valid_0's ndcg@3: 0.841134	valid_0's ndcg@4: 0.854697	valid_0's ndcg@5: 0.863824
# [29]	valid_0's ndcg@1: 0.780923	valid_0's ndcg@2: 0.820042	valid_0's ndcg@3: 0.841318	valid_0's ndcg@4: 0.854967	valid_0's ndcg@5: 0.864078
# [30]	valid_0's ndcg@1: 0.781339	valid_0's ndcg@2: 0.820402	valid_0's ndcg@3: 0.841687	valid_0's ndcg@4: 0.855212	valid_0's ndcg@5: 0.86435
# [31]	valid_0's ndcg@1: 0.781582	valid_0's ndcg@2: 0.820648	valid_0's ndcg@3: 0.8419	valid_0's ndcg@4: 0.855467	valid_0's ndcg@5: 0.864518
# [32]	valid_0's ndcg@1: 0.781835	valid_0's ndcg@2: 0.820759	valid_0's ndcg@3: 0.842024	valid_0's ndcg@4: 0.855557	valid_0's ndcg@5: 0.864655
# [33]	valid_0's ndcg@1: 0.781794	valid_0's ndcg@2: 0.820851	valid_0's ndcg@3: 0.842149	valid_0's ndcg@4: 0.855576	valid_0's ndcg@5: 0.864722
# [34]	valid_0's ndcg@1: 0.781865	valid_0's ndcg@2: 0.821007	valid_0's ndcg@3: 0.842235	valid_0's ndcg@4: 0.855678	valid_0's ndcg@5: 0.864805
# [35]	valid_0's ndcg@1: 0.78189	valid_0's ndcg@2: 0.820969	valid_0's ndcg@3: 0.842258	valid_0's ndcg@4: 0.855693	valid_0's ndcg@5: 0.864737
# [36]	valid_0's ndcg@1: 0.78193	valid_0's ndcg@2: 0.82095	valid_0's ndcg@3: 0.84235	valid_0's ndcg@4: 0.855692	valid_0's ndcg@5: 0.864835
# [37]	valid_0's ndcg@1: 0.7819	valid_0's ndcg@2: 0.821218	valid_0's ndcg@3: 0.842444	valid_0's ndcg@4: 0.855865	valid_0's ndcg@5: 0.865029
# [38]	valid_0's ndcg@1: 0.781956	valid_0's ndcg@2: 0.821296	valid_0's ndcg@3: 0.842569	valid_0's ndcg@4: 0.855921	valid_0's ndcg@5: 0.865127
# [39]	valid_0's ndcg@1: 0.78227	valid_0's ndcg@2: 0.821555	valid_0's ndcg@3: 0.842744	valid_0's ndcg@4: 0.856069	valid_0's ndcg@5: 0.865308
# [40]	valid_0's ndcg@1: 0.782381	valid_0's ndcg@2: 0.821534	valid_0's ndcg@3: 0.84276	valid_0's ndcg@4: 0.856125	valid_0's ndcg@5: 0.865297
# [41]	valid_0's ndcg@1: 0.782422	valid_0's ndcg@2: 0.821545	valid_0's ndcg@3: 0.842781	valid_0's ndcg@4: 0.85616	valid_0's ndcg@5: 0.865322
# [42]	valid_0's ndcg@1: 0.782417	valid_0's ndcg@2: 0.821731	valid_0's ndcg@3: 0.842813	valid_0's ndcg@4: 0.856235	valid_0's ndcg@5: 0.865468
# [43]	valid_0's ndcg@1: 0.78222	valid_0's ndcg@2: 0.821552	valid_0's ndcg@3: 0.842715	valid_0's ndcg@4: 0.856144	valid_0's ndcg@5: 0.865309
# [44]	valid_0's ndcg@1: 0.782291	valid_0's ndcg@2: 0.821534	valid_0's ndcg@3: 0.842815	valid_0's ndcg@4: 0.856195	valid_0's ndcg@5: 0.865369
# [45]	valid_0's ndcg@1: 0.782448	valid_0's ndcg@2: 0.821785	valid_0's ndcg@3: 0.842979	valid_0's ndcg@4: 0.856344	valid_0's ndcg@5: 0.865504
# [46]	valid_0's ndcg@1: 0.782569	valid_0's ndcg@2: 0.821829	valid_0's ndcg@3: 0.843134	valid_0's ndcg@4: 0.856399	valid_0's ndcg@5: 0.865572
# [47]	valid_0's ndcg@1: 0.78268	valid_0's ndcg@2: 0.821818	valid_0's ndcg@3: 0.843192	valid_0's ndcg@4: 0.856498	valid_0's ndcg@5: 0.865586
# [48]	valid_0's ndcg@1: 0.782675	valid_0's ndcg@2: 0.821925	valid_0's ndcg@3: 0.84328	valid_0's ndcg@4: 0.856581	valid_0's ndcg@5: 0.865661
# [49]	valid_0's ndcg@1: 0.78264	valid_0's ndcg@2: 0.821844	valid_0's ndcg@3: 0.843248	valid_0's ndcg@4: 0.856529	valid_0's ndcg@5: 0.865573
# [50]	valid_0's ndcg@1: 0.782503	valid_0's ndcg@2: 0.82185	valid_0's ndcg@3: 0.843219	valid_0's ndcg@4: 0.856554	valid_0's ndcg@5: 0.865535
# [51]	valid_0's ndcg@1: 0.78267	valid_0's ndcg@2: 0.82181	valid_0's ndcg@3: 0.84329	valid_0's ndcg@4: 0.856492	valid_0's ndcg@5: 0.8656
# [52]	valid_0's ndcg@1: 0.782964	valid_0's ndcg@2: 0.822156	valid_0's ndcg@3: 0.843442	valid_0's ndcg@4: 0.856711	valid_0's ndcg@5: 0.865873
# [53]	valid_0's ndcg@1: 0.782918	valid_0's ndcg@2: 0.822183	valid_0's ndcg@3: 0.843475	valid_0's ndcg@4: 0.856729	valid_0's ndcg@5: 0.865905
# [54]	valid_0's ndcg@1: 0.782964	valid_0's ndcg@2: 0.822241	valid_0's ndcg@3: 0.843499	valid_0's ndcg@4: 0.856753	valid_0's ndcg@5: 0.865907
# [55]	valid_0's ndcg@1: 0.78309	valid_0's ndcg@2: 0.822482	valid_0's ndcg@3: 0.843706	valid_0's ndcg@4: 0.85703	valid_0's ndcg@5: 0.866113
# [56]	valid_0's ndcg@1: 0.783217	valid_0's ndcg@2: 0.822514	valid_0's ndcg@3: 0.843732	valid_0's ndcg@4: 0.857034	valid_0's ndcg@5: 0.866116
# [57]	valid_0's ndcg@1: 0.783242	valid_0's ndcg@2: 0.822546	valid_0's ndcg@3: 0.843823	valid_0's ndcg@4: 0.85711	valid_0's ndcg@5: 0.866179
# [58]	valid_0's ndcg@1: 0.783293	valid_0's ndcg@2: 0.822633	valid_0's ndcg@3: 0.843831	valid_0's ndcg@4: 0.857155	valid_0's ndcg@5: 0.866255
# [59]	valid_0's ndcg@1: 0.783339	valid_0's ndcg@2: 0.822633	valid_0's ndcg@3: 0.843872	valid_0's ndcg@4: 0.857158	valid_0's ndcg@5: 0.866277
# [60]	valid_0's ndcg@1: 0.783358	valid_0's ndcg@2: 0.822712	valid_0's ndcg@3: 0.843828	valid_0's ndcg@4: 0.857218	valid_0's ndcg@5: 0.866253
# [61]	valid_0's ndcg@1: 0.78347	valid_0's ndcg@2: 0.822693	valid_0's ndcg@3: 0.843917	valid_0's ndcg@4: 0.857221	valid_0's ndcg@5: 0.866335
# [62]	valid_0's ndcg@1: 0.783536	valid_0's ndcg@2: 0.822737	valid_0's ndcg@3: 0.843936	valid_0's ndcg@4: 0.857266	valid_0's ndcg@5: 0.8664
# [63]	valid_0's ndcg@1: 0.78384	valid_0's ndcg@2: 0.822922	valid_0's ndcg@3: 0.844135	valid_0's ndcg@4: 0.857387	valid_0's ndcg@5: 0.866551
# [64]	valid_0's ndcg@1: 0.783855	valid_0's ndcg@2: 0.822894	valid_0's ndcg@3: 0.844063	valid_0's ndcg@4: 0.857389	valid_0's ndcg@5: 0.86654
# [65]	valid_0's ndcg@1: 0.783845	valid_0's ndcg@2: 0.822846	valid_0's ndcg@3: 0.84401	valid_0's ndcg@4: 0.857335	valid_0's ndcg@5: 0.866506
# [66]	valid_0's ndcg@1: 0.783982	valid_0's ndcg@2: 0.822853	valid_0's ndcg@3: 0.844051	valid_0's ndcg@4: 0.857354	valid_0's ndcg@5: 0.866532
# [67]	valid_0's ndcg@1: 0.783876	valid_0's ndcg@2: 0.822786	valid_0's ndcg@3: 0.844048	valid_0's ndcg@4: 0.857427	valid_0's ndcg@5: 0.866489
# [68]	valid_0's ndcg@1: 0.783815	valid_0's ndcg@2: 0.822732	valid_0's ndcg@3: 0.844077	valid_0's ndcg@4: 0.857389	valid_0's ndcg@5: 0.866477
# [69]	valid_0's ndcg@1: 0.783876	valid_0's ndcg@2: 0.822778	valid_0's ndcg@3: 0.844033	valid_0's ndcg@4: 0.857404	valid_0's ndcg@5: 0.866472
# [70]	valid_0's ndcg@1: 0.783936	valid_0's ndcg@2: 0.822816	valid_0's ndcg@3: 0.844077	valid_0's ndcg@4: 0.85746	valid_0's ndcg@5: 0.866492
# [71]	valid_0's ndcg@1: 0.783815	valid_0's ndcg@2: 0.822796	valid_0's ndcg@3: 0.844026	valid_0's ndcg@4: 0.857423	valid_0's ndcg@5: 0.866454
# [72]	valid_0's ndcg@1: 0.78385	valid_0's ndcg@2: 0.822812	valid_0's ndcg@3: 0.843985	valid_0's ndcg@4: 0.857423	valid_0's ndcg@5: 0.866463
# [73]	valid_0's ndcg@1: 0.784397	valid_0's ndcg@2: 0.823394	valid_0's ndcg@3: 0.844511	valid_0's ndcg@4: 0.85791	valid_0's ndcg@5: 0.866926
# [74]	valid_0's ndcg@1: 0.784296	valid_0's ndcg@2: 0.82332	valid_0's ndcg@3: 0.844408	valid_0's ndcg@4: 0.857822	valid_0's ndcg@5: 0.866831
# [75]	valid_0's ndcg@1: 0.784438	valid_0's ndcg@2: 0.823365	valid_0's ndcg@3: 0.844482	valid_0's ndcg@4: 0.857918	valid_0's ndcg@5: 0.866914
# [76]	valid_0's ndcg@1: 0.784433	valid_0's ndcg@2: 0.823318	valid_0's ndcg@3: 0.844502	valid_0's ndcg@4: 0.857918	valid_0's ndcg@5: 0.86691
# [77]	valid_0's ndcg@1: 0.784301	valid_0's ndcg@2: 0.823252	valid_0's ndcg@3: 0.844452	valid_0's ndcg@4: 0.857848	valid_0's ndcg@5: 0.866869
# [78]	valid_0's ndcg@1: 0.784256	valid_0's ndcg@2: 0.823253	valid_0's ndcg@3: 0.844459	valid_0's ndcg@4: 0.857819	valid_0's ndcg@5: 0.866844
# [79]	valid_0's ndcg@1: 0.784357	valid_0's ndcg@2: 0.823436	valid_0's ndcg@3: 0.844587	valid_0's ndcg@4: 0.857966	valid_0's ndcg@5: 0.866989
# [80]	valid_0's ndcg@1: 0.784433	valid_0's ndcg@2: 0.82358	valid_0's ndcg@3: 0.844691	valid_0's ndcg@4: 0.85805	valid_0's ndcg@5: 0.867073
# [81]	valid_0's ndcg@1: 0.784478	valid_0's ndcg@2: 0.823633	valid_0's ndcg@3: 0.844751	valid_0's ndcg@4: 0.858093	valid_0's ndcg@5: 0.867092
# [82]	valid_0's ndcg@1: 0.784645	valid_0's ndcg@2: 0.823824	valid_0's ndcg@3: 0.844904	valid_0's ndcg@4: 0.858232	valid_0's ndcg@5: 0.867243
# [83]	valid_0's ndcg@1: 0.784752	valid_0's ndcg@2: 0.823821	valid_0's ndcg@3: 0.844855	valid_0's ndcg@4: 0.858268	valid_0's ndcg@5: 0.86723
# [84]	valid_0's ndcg@1: 0.784782	valid_0's ndcg@2: 0.82384	valid_0's ndcg@3: 0.844904	valid_0's ndcg@4: 0.858271	valid_0's ndcg@5: 0.867216
# [85]	valid_0's ndcg@1: 0.784807	valid_0's ndcg@2: 0.823859	valid_0's ndcg@3: 0.844923	valid_0's ndcg@4: 0.858319	valid_0's ndcg@5: 0.867252
# [86]	valid_0's ndcg@1: 0.784803	valid_0's ndcg@2: 0.823931	valid_0's ndcg@3: 0.844947	valid_0's ndcg@4: 0.858408	valid_0's ndcg@5: 0.867277
# [87]	valid_0's ndcg@1: 0.784767	valid_0's ndcg@2: 0.823976	valid_0's ndcg@3: 0.844929	valid_0's ndcg@4: 0.858386	valid_0's ndcg@5: 0.867264
# [88]	valid_0's ndcg@1: 0.784848	valid_0's ndcg@2: 0.824005	valid_0's ndcg@3: 0.84498	valid_0's ndcg@4: 0.858334	valid_0's ndcg@5: 0.867277
# [89]	valid_0's ndcg@1: 0.784843	valid_0's ndcg@2: 0.82397	valid_0's ndcg@3: 0.844951	valid_0's ndcg@4: 0.858331	valid_0's ndcg@5: 0.867272
# [90]	valid_0's ndcg@1: 0.784726	valid_0's ndcg@2: 0.823932	valid_0's ndcg@3: 0.844944	valid_0's ndcg@4: 0.858288	valid_0's ndcg@5: 0.867242
# [91]	valid_0's ndcg@1: 0.784787	valid_0's ndcg@2: 0.823808	valid_0's ndcg@3: 0.844943	valid_0's ndcg@4: 0.85828	valid_0's ndcg@5: 0.867229
# [92]	valid_0's ndcg@1: 0.784904	valid_0's ndcg@2: 0.823869	valid_0's ndcg@3: 0.844954	valid_0's ndcg@4: 0.858331	valid_0's ndcg@5: 0.867327
# [93]	valid_0's ndcg@1: 0.785112	valid_0's ndcg@2: 0.824153	valid_0's ndcg@3: 0.845174	valid_0's ndcg@4: 0.858539	valid_0's ndcg@5: 0.867536
# [94]	valid_0's ndcg@1: 0.785036	valid_0's ndcg@2: 0.824096	valid_0's ndcg@3: 0.845071	valid_0's ndcg@4: 0.858465	valid_0's ndcg@5: 0.867466
# [95]	valid_0's ndcg@1: 0.784995	valid_0's ndcg@2: 0.824032	valid_0's ndcg@3: 0.84506	valid_0's ndcg@4: 0.858478	valid_0's ndcg@5: 0.867449
# [96]	valid_0's ndcg@1: 0.785016	valid_0's ndcg@2: 0.824042	valid_0's ndcg@3: 0.845072	valid_0's ndcg@4: 0.858451	valid_0's ndcg@5: 0.867441
# [97]	valid_0's ndcg@1: 0.785026	valid_0's ndcg@2: 0.824054	valid_0's ndcg@3: 0.845072	valid_0's ndcg@4: 0.858511	valid_0's ndcg@5: 0.867433
# [98]	valid_0's ndcg@1: 0.784975	valid_0's ndcg@2: 0.823997	valid_0's ndcg@3: 0.845024	valid_0's ndcg@4: 0.858448	valid_0's ndcg@5: 0.867415
# [99]	valid_0's ndcg@1: 0.785046	valid_0's ndcg@2: 0.824105	valid_0's ndcg@3: 0.845092	valid_0's ndcg@4: 0.858485	valid_0's ndcg@5: 0.867491
# [100]	valid_0's ndcg@1: 0.784965	valid_0's ndcg@2: 0.824084	valid_0's ndcg@3: 0.845196	valid_0's ndcg@4: 0.858518	valid_0's ndcg@5: 0.867492
# LGBMRanker(boosting_type='dart', early_stopping_rounds=10, feature_fraction=0.8,
#            is_unbalance=True, learning_rate=0.15, max_depth=15, metric='ndcg',
#            num_iterations=100, num_leaves=25, objective='rank_xendcg',
#            subsample=0.2)

# %%
test_pred = gbm.predict(X_val)

print(test_pred)
# Out:
# [-0.04850601 -0.24622072  0.21122961 ...  0.04796483  0.07546289
#  -0.23179927]

# %%
X_val["predicted_ranking"] = test_pred

# %%
print("--> NDCG : ", ndcg_score([y_val],[X_val["predicted_ranking"]]))
# Out:
# --> NDCG :  0.7681402432767066

# %%
del training_data, aux_training
gc.collect()
# Out:
# 2

# %%
#Feature eng for test data
z = test_data['prop_id'].value_counts() 
z1 = z.to_dict() #converts to dictionary
test_data['Count_Column'] = test_data['prop_id'].map(z1)

#Create one location score column
test_data['prop_loc_score1_norm'] = test_data['prop_location_score1'] / test_data['prop_location_score1'].abs().max()
test_data['prop_location_score2'].fillna(test_data['prop_loc_score1_norm'], inplace=True)
test_data['location_score'] = (test_data['prop_loc_score1_norm'] + test_data['prop_location_score2'])/2
test_data = test_data.drop('prop_loc_score1_norm', axis=1)
# test_data['location_score'] = ((test_data['prop_location_score1'] + test_data['prop_location_score2']) / 2)

# %%
test_data['diff_price'] = ((test_data['price_usd']) - (np.exp(test_data['prop_log_historical_price'])))

# %%
test_data = replace_nan_with_mean(test_data,["visitor_hist_starrating","visitor_hist_adr_usd","diff_price"])
test_data = replace_nan_with_mean(test_data,['comp1_rate_percent_diff','comp1_rate','comp2_rate_percent_diff','comp2_rate',
                                 'comp3_rate_percent_diff','comp3_rate','comp4_rate_percent_diff','comp4_rate',
                                 'comp5_rate_percent_diff','comp5_rate','comp6_rate_percent_diff','comp6_rate',
                                 'comp7_rate_percent_diff','comp7_rate','comp8_rate_percent_diff','comp8_rate'])
test_data = replace_nan_with_median(test_data,["orig_destination_distance"])

col_min = test_data["srch_query_affinity_score"].min() # minimum of col
test_data = replace_nan_with_value(test_data,'srch_query_affinity_score',col_min)

col_min = test_data["prop_starrating"].min() # minimum of col
test_data = replace_nan_with_value(test_data,'prop_starrating',col_min)

col_min = test_data["prop_review_score"].min() # minimum of col
test_data = replace_nan_with_value(test_data,'prop_review_score',col_min)

col_min = test_data["location_score"].min() # minimum of col
test_data = replace_nan_with_value(test_data,'location_score',col_min)

# %%
#Average competition data
#Get whether diff with competition was pos/neg, then get average diff 
test_data['comp_rate_percent_diff'] = (((test_data['comp1_rate_percent_diff'] * test_data['comp1_rate']) +
                                            (test_data['comp2_rate_percent_diff'] * test_data['comp2_rate']) +
                                            (test_data['comp3_rate_percent_diff'] * test_data['comp3_rate']) +
                                            (test_data['comp4_rate_percent_diff'] * test_data['comp4_rate']) + 
                                            (test_data['comp5_rate_percent_diff'] * test_data['comp5_rate']) +
                                            (test_data['comp6_rate_percent_diff'] * test_data['comp6_rate']) +
                                            (test_data['comp7_rate_percent_diff'] * test_data['comp7_rate']) +
                                            (test_data['comp8_rate_percent_diff'] * test_data['comp8_rate'])) / 8)

# %%
test_data = test_data.drop(['date_time'], axis=1)
test_data = test_data.drop(['prop_location_score1'], axis=1)
test_data = test_data.drop(['prop_location_score2'], axis=1)
test_data = test_data.drop(['comp1_rate_percent_diff','comp1_rate','comp2_rate_percent_diff','comp2_rate',
                                 'comp3_rate_percent_diff','comp3_rate','comp4_rate_percent_diff','comp4_rate',
                                 'comp5_rate_percent_diff','comp5_rate','comp6_rate_percent_diff','comp6_rate',
                                 'comp7_rate_percent_diff','comp7_rate','comp8_rate_percent_diff','comp8_rate'], axis=1)

# %%
gc.collect()
# Out:
# 63

# %%
test_data
# Out:
#          srch_id  site_id  visitor_location_country_id  \
# 0              1       24                          216
# 1              1       24                          216
# 2              1       24                          216
# 3              1       24                          216
# 4              1       24                          216
# ...          ...      ...                          ...
# 4959178   332787       24                          216
# 4959179   332787       24                          216
# 4959180   332787       24                          216
# 4959181   332787       24                          216
# 4959182   332787       24                          216
#
#          visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  \
# 0                       3.374933             177.15073              219
# 1                       3.374933             177.15073              219
# 2                       3.374933             177.15073              219
# 3                       3.374933             177.15073              219
# 4                       3.374933             177.15073              219
# ...                          ...                   ...              ...
# 4959178                 3.374933             177.15073              117
# 4959179                 3.374933             177.15073              117
# 4959180                 3.374933             177.15073              117
# 4959181                 3.374933             177.15073              117
# 4959182                 3.374933             177.15073              117
#
#          prop_id  prop_starrating  prop_review_score  prop_brand_bool  ...  \
# 0           3180                3                4.5                1  ...
# 1           5543                3                4.5                1  ...
# 2          14142                2                3.5                1  ...
# 3          22393                3                4.5                1  ...
# 4          24194                3                4.5                1  ...
# ...          ...              ...                ...              ...  ...
# 4959178    32019                4                3.5                0  ...
# 4959179    33959                4                3.0                1  ...
# 4959180    35240                4                0.0                0  ...
# 4959181    94437                4                0.0                0  ...
# 4959182    99509                4                4.5                1  ...
#
#          comp3_inv  comp4_inv  comp5_inv  comp6_inv  comp7_inv  comp8_inv  \
# 0              NaN        NaN        NaN        NaN        NaN        NaN
# 1              NaN        NaN        NaN        NaN        NaN        NaN
# 2              NaN        NaN        0.0        NaN        NaN        NaN
# 3              NaN        NaN        0.0        NaN        NaN        NaN
# 4              NaN        NaN        0.0        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 4959178        0.0        0.0        0.0        NaN        NaN        NaN
# 4959179        0.0        0.0        0.0        NaN        NaN        NaN
# 4959180        0.0        0.0        0.0        NaN        NaN        NaN
# 4959181        0.0        0.0        0.0        NaN        NaN        NaN
# 4959182        0.0        0.0        0.0        NaN        NaN        NaN
#
#          Count_Column  location_score  diff_price  comp_rate_percent_diff
# 0                 185        0.245152  -33.933013               15.310530
# 1                 252        0.231262  -20.379512               15.188376
# 2                 150        0.221926  -15.071523               16.361767
# 3                 147        0.199970   -9.933013               15.111767
# 4                 214        0.315102  -33.168253               15.111767
# ...               ...             ...         ...                     ...
# 4959178            13        0.205200  -26.688561               33.342988
# 4959179            13        0.324793  -13.540419               18.092988
# 4959180             2        0.256447  -29.634348               22.217988
# 4959181             7        0.257002  -37.474348               23.092988
# 4959182            12        0.166197  -21.484348               15.342988
#
# [4959183 rows x 35 columns]

# %%
test_pred = gbm.predict(test_data)

# %%
test_pred
# Out:
# array([ 0.19057166,  0.18946773,  0.18960132, ...,  0.03564552,
#        -0.01975265,  0.55385819])

# %%
test_data["predicted_ranking"] = test_pred
test_data.head(15)
# Out:
#     srch_id  site_id  visitor_location_country_id  visitor_hist_starrating  \
# 0         1       24                          216                 3.374933
# 1         1       24                          216                 3.374933
# 2         1       24                          216                 3.374933
# 3         1       24                          216                 3.374933
# 4         1       24                          216                 3.374933
# 5         1       24                          216                 3.374933
# 6         1       24                          216                 3.374933
# 7         1       24                          216                 3.374933
# 8         1       24                          216                 3.374933
# 9         1       24                          216                 3.374933
# 10        1       24                          216                 3.374933
# 11        1       24                          216                 3.374933
# 12        1       24                          216                 3.374933
# 13        1       24                          216                 3.374933
# 14        1       24                          216                 3.374933
#
#     visitor_hist_adr_usd  prop_country_id  prop_id  prop_starrating  \
# 0              177.15073              219     3180                3
# 1              177.15073              219     5543                3
# 2              177.15073              219    14142                2
# 3              177.15073              219    22393                3
# 4              177.15073              219    24194                3
# 5              177.15073              219    28181                3
# 6              177.15073              219    34263                3
# 7              177.15073              219    37567                2
# 8              177.15073              219    50162                2
# 9              177.15073              219    54937                3
# 10             177.15073              219    56050                3
# 11             177.15073              219    61632                0
# 12             177.15073              219    61934                3
# 13             177.15073              219    63894                3
# 14             177.15073              219    72090                3
#
#     prop_review_score  prop_brand_bool  ...  comp4_inv  comp5_inv  comp6_inv  \
# 0                 4.5                1  ...        NaN        NaN        NaN
# 1                 4.5                1  ...        NaN        NaN        NaN
# 2                 3.5                1  ...        NaN        0.0        NaN
# 3                 4.5                1  ...        NaN        0.0        NaN
# 4                 4.5                1  ...        NaN        0.0        NaN
# 5                 4.5                1  ...        NaN        NaN        NaN
# 6                 4.5                1  ...        NaN        0.0        NaN
# 7                 4.5                0  ...        NaN        0.0        NaN
# 8                 3.5                1  ...        NaN        0.0        NaN
# 9                 4.0                1  ...        NaN        0.0        NaN
# 10                4.0                1  ...        NaN        1.0        NaN
# 11                0.0                0  ...        NaN        NaN        NaN
# 12                4.5                1  ...        NaN        NaN        NaN
# 13                4.5                1  ...        NaN        0.0        NaN
# 14                4.0                1  ...        NaN        0.0        NaN
#
#     comp7_inv  comp8_inv  Count_Column  location_score  diff_price  \
# 0         NaN        NaN           185        0.245152  -33.933013
# 1         NaN        NaN           252        0.231262  -20.379512
# 2         NaN        NaN           150        0.221926  -15.071523
# 3         NaN        NaN           147        0.199970   -9.933013
# 4         NaN        NaN           214        0.315102  -33.168253
# 5         NaN        NaN           381        0.256056  -23.620073
# 6         NaN        NaN           202        0.286347  -23.514064
# 7         NaN        NaN           175        0.209622  -14.956540
# 8         NaN        NaN           293        0.197993  -28.267134
# 9         NaN        NaN           403        0.231447  -32.284285
# 10        NaN        NaN           141        0.258924   46.505570
# 11        NaN        NaN            72        0.224565  -56.494032
# 12        NaN        NaN           377        0.328270  -19.973180
# 13        NaN        NaN           168        0.311474  -27.650664
# 14        NaN        NaN           184        0.230320  -62.174964
#
#     comp_rate_percent_diff  predicted_ranking
# 0                15.310530           0.190572
# 1                15.188376           0.189468
# 2                16.361767           0.189601
# 3                15.111767           0.041115
# 4                15.111767           0.463463
# 5                15.310530           0.396112
# 6                15.111767           0.450557
# 7                19.861767           0.520495
# 8                13.861767           0.440089
# 9                15.233922           0.765054
# 10               15.310530          -0.349262
# 11               16.813376          -0.552451
# 12               15.188376           0.706167
# 13               15.111767           0.237561
# 14               15.111767           0.325717
#
# [15 rows x 36 columns]

# %%
test_data = test_data.sort_values(["srch_id","predicted_ranking"], ascending=[True,False])

# %%
test_data.drop(test_data.columns.difference(['srch_id','prop_id']), 1, inplace=True)
test_data.head()
# Out:
# C:\Users\sandr\AppData\Local\Temp/ipykernel_15112/1689140319.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   test_data.drop(test_data.columns.difference(['srch_id','prop_id']), 1, inplace=True)
#     srch_id  prop_id
# 23        1    99484
# 9         1    54937
# 12        1    61934
# 20        1    90385
# 7         1    37567

# %%
# Create output file for competition
test_data.to_csv("output.csv", index=False)
